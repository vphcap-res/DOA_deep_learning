# %% [markdown]
# <a href="https://colab.research.google.com/github/vphcap-res/DOA_deep_learning/blob/main/DOA_Deep_20241121_1210.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Data prep**

# %%
import numpy as np
import pandas as pd
import random
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
import os

# %%
# Set random seeds
np.random.seed(42)
tf.random.set_seed(42)
random.seed(42)

# %%
# Ensure deterministic TensorFlow behavior
os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

# %%
# Assuming the uploaded file is named 'DOA-managed.xlsx'
df = pd.read_excel('DOA-managed.xlsx')

# %%
# Select relevant columns
columns_to_select = ['distance', 'head', 'age', 'meanbw', 'temp', 'season', 'timegr', 'timetrans_min', 'lairagetime', 'classdoa']
df2 = df[columns_to_select]

# %%
# Encode the target variable (classdoa)
label_encoder = LabelEncoder()
df2.loc[:, 'classdoa'] = label_encoder.fit_transform(df2['classdoa'])
target = to_categorical(df2['classdoa'])  # One-hot encode the target variable

# %%
# Perform stratified splitting before preprocessing
predictors = df2.drop('classdoa', axis=1)
X_train, X_test, y_train, y_test = train_test_split(
    predictors,  # Features
    target,      # Labels
    test_size=0.2,  # 20% test set
    random_state=42,  # Reproducibility
    stratify=target   # Preserve class distribution
)

# %%
# Preprocess the training and testing data
X_train = pd.get_dummies(X_train, columns=['season', 'timegr'], drop_first=True)
X_test = pd.get_dummies(X_test, columns=['season', 'timegr'], drop_first=True)

# %%
# Ensure the columns in both sets match
X_test = X_test.reindex(columns=X_train.columns, fill_value=0)

# %%
# Define EarlyStopping
early_stopping_monitor = EarlyStopping(patience=3, restore_best_weights=True)

# %% [markdown]
# # **Experiments: Selection of baseline model**

# %% [markdown]
# **Model 1:** Hidden layer = 1, Dense = 100

# %%
# -------------------------- Model 1 -----------------------------------
# Specify Model 1: Hidden layer = 1, Dense = 100
model1 = Sequential([
    Input(shape=(X_train.shape[1],)),
    Dense(100, activation='relu'),
    Dense(2, activation='softmax')
])

# Compile the model
model1.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train Model 1
model1_training = model1.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=30,
    callbacks=[early_stopping_monitor],
    shuffle=False,
    verbose=1
)
# Out:
# Epoch 1/30
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.5519 - loss: 4.4003 - val_accuracy: 0.5859 - val_loss: 1.9827
# Epoch 2/30
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5606 - loss: 1.8188 - val_accuracy: 0.4804 - val_loss: 1.6362
# Epoch 3/30
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5895 - loss: 1.1834 - val_accuracy: 0.6360 - val_loss: 0.8212
# Epoch 4/30
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6163 - loss: 0.9410 - val_accuracy: 0.6536 - val_loss: 0.7441
# Epoch 5/30
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6318 - loss: 0.7427 - val_accuracy: 0.6468 - val_loss: 0.7919
# Epoch 6/30
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6448 - loss: 0.7308 - val_accuracy: 0.6455 - val_loss: 0.8106
# Epoch 7/30
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6427 - loss: 0.7443 - val_accuracy: 0.6468 - val_loss: 0.7751

# %%
# Evaluate Model 1
test_loss1, test_accuracy1 = model1.evaluate(X_test, y_test, verbose=0)
print(f"Model 1 - Test Loss: {test_loss1:.4f}, Test Accuracy: {test_accuracy1:.4f}")
# Out:
# Model 1 - Test Loss: 0.7441, Test Accuracy: 0.6536

# %% [markdown]
# **Model 2:** Hidden layer = 2, Dense = 100

# %%
# -------------------------- Model 2 -----------------------------------
# Specify Model 2: Hidden layer = 2, Dense = 100
model2 = Sequential([
    Input(shape=(X_train.shape[1],)),
    Dense(100, activation='relu'),
    Dense(100, activation='relu'),
    Dense(2, activation='softmax')
])

# Compile the model
model2.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train Model 2
model2_training = model2.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=30,
    callbacks=[early_stopping_monitor],
    shuffle=False,
    verbose=1
)
# Out:
# Epoch 1/30
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5605 - loss: 11.8798 - val_accuracy: 0.4005 - val_loss: 1.5306
# Epoch 2/30
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5760 - loss: 1.4201 - val_accuracy: 0.6468 - val_loss: 0.6887
# Epoch 3/30
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5886 - loss: 1.3965 - val_accuracy: 0.6522 - val_loss: 0.6981
# Epoch 4/30
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5675 - loss: 1.8210 - val_accuracy: 0.6563 - val_loss: 0.6702
# Epoch 5/30
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5984 - loss: 0.9202 - val_accuracy: 0.6401 - val_loss: 0.8363
# Epoch 6/30
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6212 - loss: 0.9391 - val_accuracy: 0.4317 - val_loss: 1.0748
# Epoch 7/30
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5758 - loss: 1.4534 - val_accuracy: 0.6130 - val_loss: 3.1766

# %%
# Evaluate Model 2
test_loss2, test_accuracy2 = model2.evaluate(X_test, y_test, verbose=0)
print(f"Model 2 - Test Loss: {test_loss2:.4f}, Test Accuracy: {test_accuracy2:.4f}")
# Out:
# Model 2 - Test Loss: 0.6702, Test Accuracy: 0.6563

# %% [markdown]
# **Model 3:** Hidden layer = 1, Dense = 200

# %%
# -------------------------- Model 3 -----------------------------------
# Specify Model 3: Hidden layer = 1, Dense = 200
model3 = Sequential([
    Input(shape=(X_train.shape[1],)),
    Dense(200, activation='relu'),
    Dense(2, activation='softmax')
])

# Compile the model
model3.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train Model 3
model3_training = model3.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=30,
    callbacks=[early_stopping_monitor],
    shuffle=False,
    verbose=1
)
# Out:
# Epoch 1/30
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5052 - loss: 32.2159 - val_accuracy: 0.6198 - val_loss: 0.7366
# Epoch 2/30
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5626 - loss: 1.8163 - val_accuracy: 0.6238 - val_loss: 1.8877
# Epoch 3/30
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5907 - loss: 1.3967 - val_accuracy: 0.7023 - val_loss: 0.6156
# Epoch 4/30
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6426 - loss: 0.8904 - val_accuracy: 0.6955 - val_loss: 0.6004
# Epoch 5/30
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6535 - loss: 0.7646 - val_accuracy: 0.6725 - val_loss: 0.7021
# Epoch 6/30
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6362 - loss: 0.8028 - val_accuracy: 0.6563 - val_loss: 0.7906
# Epoch 7/30
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6365 - loss: 0.8073 - val_accuracy: 0.6468 - val_loss: 0.8263

# %%
# Evaluate Model 3
test_loss3, test_accuracy3 = model3.evaluate(X_test, y_test, verbose=0)
print(f"Model 3 - Test Loss: {test_loss3:.4f}, Test Accuracy: {test_accuracy3:.4f}")
# Out:
# Model 3 - Test Loss: 0.6004, Test Accuracy: 0.6955

# %% [markdown]
# **Model 4:** Hidden layer = 2, Dense = 200

# %%
# -------------------------- Model 4 -----------------------------------
# Specify Model 4: Hidden layer = 2, Dense = 200
model4 = Sequential([
    Input(shape=(X_train.shape[1],)),
    Dense(200, activation='relu'),
    Dense(200, activation='relu'),
    Dense(2, activation='softmax')
])

# Compile the model
model4.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train Model 1
model4_training = model4.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=30,
    callbacks=[early_stopping_monitor],
    shuffle=False,
    verbose=1
)
# Out:
# Epoch 1/30
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.5427 - loss: 18.3666 - val_accuracy: 0.5589 - val_loss: 0.8908
# Epoch 2/30
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5511 - loss: 3.9582 - val_accuracy: 0.6401 - val_loss: 1.3925
# Epoch 3/30
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5560 - loss: 5.9135 - val_accuracy: 0.6103 - val_loss: 4.2220

# %%
# Evaluate Model 4
test_loss4, test_accuracy4 = model4.evaluate(X_test, y_test, verbose=0)
print(f"Model 4 - Test Loss: {test_loss4:.4f}, Test Accuracy: {test_accuracy4:.4f}")
# Out:
# Model 4 - Test Loss: 0.8908, Test Accuracy: 0.5589

# %% [markdown]
# ## Visualize train performance

# %%
# Create the plot
plt.plot(model1_training.history['val_loss'], 'r', model2_training.history['val_loss'], 'b',
         model3_training.history['val_loss'], 'g', model4_training.history['val_loss'], 'black')
plt.xlabel('Epochs')
plt.ylabel('Validation score')
plt.show()

# %% [markdown]
# ## Model3 compute confusion matrix

# %%
from sklearn.metrics import confusion_matrix, classification_report

# Predict class probabilities on the test set
y_pred_prob = model3.predict(X_test)

# Convert probabilities to predicted class labels
y_pred = np.argmax(y_pred_prob, axis=1)  # Get the index of the maximum value in each row
y_true = np.argmax(y_test, axis=1)       # True class labels from one-hot encoding

# Compute the confusion matrix
cm = confusion_matrix(y_true, y_pred)
print("Confusion Matrix:")
print(cm)

# Compute other metrics (precision, recall, F1-score, and support)
report = classification_report(y_true, y_pred, target_names=label_encoder.classes_)
print("\nClassification Report:")
print(report)
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Confusion Matrix:
# [[126 164]
#  [ 61 388]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         high       0.67      0.43      0.53       290
#          low       0.70      0.86      0.78       449
#
#     accuracy                           0.70       739
#    macro avg       0.69      0.65      0.65       739
# weighted avg       0.69      0.70      0.68       739

# %% [markdown]
# # **Select Model 3 for further optimization**
# ### **Model 3_1:** increase Dense = 400

# %%
# -------------------------- Model 3_1 -----------------------------------
# Specify Model 3_1: Hidden layer = 1, Dense = 400
model3_1 = Sequential([
    Input(shape=(X_train.shape[1],)),
    Dense(400, activation='relu'),  # Adjusted Dense units to 400
    Dense(2, activation='softmax')  # Output layer for binary classification
])

# Compile the model
model3_1.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train Model 3_1
model3_1_training = model3_1.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),  # Validation set
    epochs=30,
    callbacks=[early_stopping_monitor],  # Early stopping for preventing overfitting
    shuffle=False,
    verbose=1
)

# Evaluate Model 3_1
test_loss3_1, test_accuracy3_1 = model3_1.evaluate(X_test, y_test, verbose=0)

# Print performance
print(f"Model 3_1 - Test Loss: {test_loss3_1:.4f}, Test Accuracy: {test_accuracy3_1:.4f}")
# Out:
# Epoch 1/30
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5255 - loss: 6.9549 - val_accuracy: 0.6549 - val_loss: 0.6202
# Epoch 2/30
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5768 - loss: 1.4437 - val_accuracy: 0.4290 - val_loss: 1.1894
# Epoch 3/30
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5813 - loss: 1.4949 - val_accuracy: 0.6062 - val_loss: 0.6921
# Model 3_1 - Test Loss: 0.6202, Test Accuracy: 0.6549

# %% [markdown]
# ### **Model 3_2:** add ReduceLROnPlateau

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau

# -------------------------- Model 3_2 -----------------------------------
# Specify Model 3_2: Hidden layer = 1, Dense = 200, with ReduceLROnPlateau
model3_2 = Sequential([
    Input(shape=(X_train.shape[1],)),
    Dense(200, activation='relu'),
    Dense(2, activation='softmax')
])

# Compile the model
model3_2.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Define ReduceLROnPlateau callback
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',   # Monitor validation loss
    factor=0.1,           # Reduce learning rate by this factor
    patience=3,           # Number of epochs with no improvement before reducing
    min_lr=1e-6,          # Minimum learning rate
    verbose=1             # Display learning rate adjustment in logs
)

# Train Model 3_2
model3_2_training = model3_2.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=30,
    callbacks=[early_stopping_monitor, reduce_lr],  # Add ReduceLROnPlateau
    shuffle=False,
    verbose=1
)

# Evaluate Model 3_2
test_loss3_2, test_accuracy3_2 = model3_2.evaluate(X_test, y_test, verbose=0)
print(f"Model 3_2 - Test Loss: {test_loss3_2:.4f}, Test Accuracy: {test_accuracy3_2:.4f}")
# Out:
# Epoch 1/30
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5347 - loss: 4.4556 - val_accuracy: 0.6198 - val_loss: 0.7873 - learning_rate: 0.0010
# Epoch 2/30
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5770 - loss: 0.8512 - val_accuracy: 0.6509 - val_loss: 0.7950 - learning_rate: 0.0010
# Epoch 3/30
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5781 - loss: 0.8811 - val_accuracy: 0.6414 - val_loss: 0.9124 - learning_rate: 0.0010
# Model 3_2 - Test Loss: 0.7873, Test Accuracy: 0.6198

# %% [markdown]
# ## **Model 3_3:** increase patience in Early Stop and in ReduceLROnPlateau

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# -------------------------- Model 3_3 -----------------------------------
# Specify Model 3_3: Same architecture as Model 3
model3_3 = Sequential([
    Input(shape=(X_train.shape[1],)),
    Dense(200, activation='relu'),
    Dense(2, activation='softmax')
])

# Compile the model
model3_3.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Define callbacks with increased patience
early_stopping_monitor_3_3 = EarlyStopping(
    patience=10,  # Increased patience for early stopping
    restore_best_weights=True,
    verbose=1
)

reduce_lr_3_3 = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.1,
    patience=7,  # Increased patience for ReduceLROnPlateau
    min_lr=1e-6,
    verbose=1
)

# Train Model 3_3
model3_3_training = model3_3.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=50,  # Allow more epochs to observe the impact of increased patience
    callbacks=[early_stopping_monitor_3_3, reduce_lr_3_3],
    shuffle=False,
    verbose=1
)

# Evaluate Model 3_3
test_loss3_3, test_accuracy3_3 = model3_3.evaluate(X_test, y_test, verbose=0)
print(f"Model 3_3 - Test Loss: {test_loss3_3:.4f}, Test Accuracy: {test_accuracy3_3:.4f}")
# Out:
# Epoch 1/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5358 - loss: 8.9926 - val_accuracy: 0.3802 - val_loss: 1.4454 - learning_rate: 0.0010
# Epoch 2/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5379 - loss: 1.1205 - val_accuracy: 0.6211 - val_loss: 0.9239 - learning_rate: 0.0010
# Epoch 3/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6007 - loss: 0.8096 - val_accuracy: 0.6387 - val_loss: 0.8046 - learning_rate: 0.0010
# Epoch 4/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5972 - loss: 0.8118 - val_accuracy: 0.4154 - val_loss: 1.4514 - learning_rate: 0.0010
# Epoch 5/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5791 - loss: 1.3113 - val_accuracy: 0.5643 - val_loss: 0.7772 - learning_rate: 0.0010
# Epoch 6/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6347 - loss: 0.8003 - val_accuracy: 0.6915 - val_loss: 0.6244 - learning_rate: 0.0010
# Epoch 7/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6514 - loss: 0.7686 - val_accuracy: 0.6279 - val_loss: 0.6906 - learning_rate: 0.0010
# Epoch 8/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6432 - loss: 0.8273 - val_accuracy: 0.6779 - val_loss: 0.6806 - learning_rate: 0.0010
# Epoch 9/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6477 - loss: 0.7558 - val_accuracy: 0.6617 - val_loss: 0.7416 - learning_rate: 0.0010
# Epoch 10/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6458 - loss: 0.7876 - val_accuracy: 0.3978 - val_loss: 1.8181 - learning_rate: 0.0010
# Epoch 11/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5809 - loss: 1.5927 - val_accuracy: 0.6712 - val_loss: 0.6246 - learning_rate: 0.0010
# Epoch 12/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6659 - loss: 0.7318 - val_accuracy: 0.6955 - val_loss: 0.6132 - learning_rate: 0.0010
# Epoch 13/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6565 - loss: 0.7501 - val_accuracy: 0.5940 - val_loss: 0.7468 - learning_rate: 0.0010
# Epoch 14/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6255 - loss: 1.1976 - val_accuracy: 0.4235 - val_loss: 1.4510 - learning_rate: 0.0010
# Epoch 15/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6100 - loss: 1.0004 - val_accuracy: 0.6333 - val_loss: 0.6654 - learning_rate: 0.0010
# Epoch 16/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6568 - loss: 0.8021 - val_accuracy: 0.5778 - val_loss: 0.7920 - learning_rate: 0.0010
# Epoch 17/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6488 - loss: 0.8193 - val_accuracy: 0.5927 - val_loss: 0.7632 - learning_rate: 0.0010
# Epoch 18/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6442 - loss: 0.8436 - val_accuracy: 0.5940 - val_loss: 0.7570 - learning_rate: 0.0010
# Epoch 19/50
# 88/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6439 - loss: 0.8483
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6426 - loss: 0.8518 - val_accuracy: 0.6022 - val_loss: 0.7132 - learning_rate: 0.0010
# Epoch 20/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6727 - loss: 0.6379 - val_accuracy: 0.6996 - val_loss: 0.6016 - learning_rate: 1.0000e-04
# Epoch 21/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7004 - loss: 0.6065 - val_accuracy: 0.7077 - val_loss: 0.5980 - learning_rate: 1.0000e-04
# Epoch 22/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6993 - loss: 0.6073 - val_accuracy: 0.6969 - val_loss: 0.5988 - learning_rate: 1.0000e-04
# Epoch 23/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6889 - loss: 0.6092 - val_accuracy: 0.6969 - val_loss: 0.6045 - learning_rate: 1.0000e-04
# Epoch 24/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6881 - loss: 0.6113 - val_accuracy: 0.6915 - val_loss: 0.6131 - learning_rate: 1.0000e-04
# Epoch 25/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6852 - loss: 0.6130 - val_accuracy: 0.6955 - val_loss: 0.6216 - learning_rate: 1.0000e-04
# Epoch 26/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6839 - loss: 0.6135 - val_accuracy: 0.6942 - val_loss: 0.6274 - learning_rate: 1.0000e-04
# Epoch 27/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6792 - loss: 0.6126 - val_accuracy: 0.6942 - val_loss: 0.6288 - learning_rate: 1.0000e-04
# Epoch 28/50
# 65/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6837 - loss: 0.6025
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6780 - loss: 0.6108 - val_accuracy: 0.6942 - val_loss: 0.6278 - learning_rate: 1.0000e-04
# Epoch 29/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7001 - loss: 0.5865 - val_accuracy: 0.7037 - val_loss: 0.5935 - learning_rate: 1.0000e-05
# Epoch 30/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7021 - loss: 0.5809 - val_accuracy: 0.7050 - val_loss: 0.5928 - learning_rate: 1.0000e-05
# Epoch 31/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7020 - loss: 0.5808 - val_accuracy: 0.7077 - val_loss: 0.5926 - learning_rate: 1.0000e-05
# Epoch 32/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7026 - loss: 0.5808 - val_accuracy: 0.7077 - val_loss: 0.5924 - learning_rate: 1.0000e-05
# Epoch 33/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7026 - loss: 0.5807 - val_accuracy: 0.7077 - val_loss: 0.5922 - learning_rate: 1.0000e-05
# Epoch 34/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7024 - loss: 0.5807 - val_accuracy: 0.7077 - val_loss: 0.5921 - learning_rate: 1.0000e-05
# Epoch 35/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7025 - loss: 0.5807 - val_accuracy: 0.7064 - val_loss: 0.5920 - learning_rate: 1.0000e-05
# Epoch 36/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7023 - loss: 0.5806 - val_accuracy: 0.7064 - val_loss: 0.5919 - learning_rate: 1.0000e-05
# Epoch 37/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7023 - loss: 0.5806 - val_accuracy: 0.7077 - val_loss: 0.5918 - learning_rate: 1.0000e-05
# Epoch 38/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7024 - loss: 0.5806 - val_accuracy: 0.7077 - val_loss: 0.5918 - learning_rate: 1.0000e-05
# Epoch 39/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7020 - loss: 0.5806 - val_accuracy: 0.7077 - val_loss: 0.5918 - learning_rate: 1.0000e-05
# Epoch 40/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7034 - loss: 0.5807 - val_accuracy: 0.7077 - val_loss: 0.5919 - learning_rate: 1.0000e-05
# Epoch 41/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7008 - loss: 0.5807 - val_accuracy: 0.7050 - val_loss: 0.5921 - learning_rate: 1.0000e-05
# Epoch 42/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7014 - loss: 0.5808 - val_accuracy: 0.7009 - val_loss: 0.5923 - learning_rate: 1.0000e-05
# Epoch 43/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7020 - loss: 0.5809 - val_accuracy: 0.6996 - val_loss: 0.5926 - learning_rate: 1.0000e-05
# Epoch 44/50
# 85/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7017 - loss: 0.5789
# Epoch 44: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7007 - loss: 0.5810 - val_accuracy: 0.6982 - val_loss: 0.5929 - learning_rate: 1.0000e-05
# Epoch 45/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7040 - loss: 0.5797 - val_accuracy: 0.6996 - val_loss: 0.5890 - learning_rate: 1.0000e-06
# Epoch 46/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7024 - loss: 0.5766 - val_accuracy: 0.7009 - val_loss: 0.5890 - learning_rate: 1.0000e-06
# Epoch 47/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7024 - loss: 0.5766 - val_accuracy: 0.7009 - val_loss: 0.5890 - learning_rate: 1.0000e-06
# Epoch 48/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7024 - loss: 0.5766 - val_accuracy: 0.7009 - val_loss: 0.5890 - learning_rate: 1.0000e-06
# Epoch 49/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7024 - loss: 0.5766 - val_accuracy: 0.7009 - val_loss: 0.5891 - learning_rate: 1.0000e-06
# Epoch 50/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7024 - loss: 0.5766 - val_accuracy: 0.7009 - val_loss: 0.5891 - learning_rate: 1.0000e-06
# Restoring model weights from the end of the best epoch: 45.
# Model 3_3 - Test Loss: 0.5890, Test Accuracy: 0.6996

# %% [markdown]
# ## **Model 3_4:** continue with model3_3 & add dropout

# %%
from tensorflow.keras.layers import Dropout

# -------------------------- Model 3_4 -----------------------------------
# Specify Model 3_4: Add dropout layers to the architecture
model3_4 = Sequential([
    Input(shape=(X_train.shape[1],)),
    Dense(200, activation='relu'),
    Dropout(0.3),  # Add dropout with 30% rate
    Dense(2, activation='softmax')
])

# Compile the model
model3_4.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Define callbacks (same as in model3_3)
early_stopping_monitor_3_4 = EarlyStopping(
    patience=10,  # Same patience for early stopping as model3_3
    restore_best_weights=True,
    verbose=1
)

reduce_lr_3_4 = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.1,
    patience=7,  # Same patience for ReduceLROnPlateau as model3_3
    min_lr=1e-6,
    verbose=1
)

# Train Model 3_4
model3_4_training = model3_4.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=50,  # Keep the same number of epochs
    callbacks=[early_stopping_monitor_3_4, reduce_lr_3_4],
    shuffle=False,
    verbose=1
)

# Evaluate Model 3_4
test_loss3_4, test_accuracy3_4 = model3_4.evaluate(X_test, y_test, verbose=0)
print(f"Model 3_4 - Test Loss: {test_loss3_4:.4f}, Test Accuracy: {test_accuracy3_4:.4f}")

# Get confusion matrix and classification metrics
from sklearn.metrics import confusion_matrix, classification_report

# Predict on test set
y_pred3_4 = model3_4.predict(X_test)
y_pred3_4_classes = y_pred3_4.argmax(axis=1)
y_test_classes = y_test.argmax(axis=1)

# Compute confusion matrix
conf_matrix3_4 = confusion_matrix(y_test_classes, y_pred3_4_classes)
print("\nConfusion Matrix:")
print(conf_matrix3_4)

# Compute classification report
class_report3_4 = classification_report(y_test_classes, y_pred3_4_classes, target_names=label_encoder.classes_)
print("\nClassification Report:")
print(class_report3_4)
# Out:
# Epoch 1/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5034 - loss: 62.1860 - val_accuracy: 0.6103 - val_loss: 4.2763 - learning_rate: 0.0010
# Epoch 2/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5347 - loss: 27.5059 - val_accuracy: 0.6157 - val_loss: 1.6300 - learning_rate: 0.0010
# Epoch 3/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5252 - loss: 17.3830 - val_accuracy: 0.6265 - val_loss: 1.6468 - learning_rate: 0.0010
# Epoch 4/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5778 - loss: 8.3031 - val_accuracy: 0.6441 - val_loss: 0.8504 - learning_rate: 0.0010
# Epoch 5/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5571 - loss: 4.2789 - val_accuracy: 0.6401 - val_loss: 0.9189 - learning_rate: 0.0010
# Epoch 6/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5651 - loss: 1.7562 - val_accuracy: 0.6143 - val_loss: 1.0774 - learning_rate: 0.0010
# Epoch 7/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5802 - loss: 0.9177 - val_accuracy: 0.6455 - val_loss: 0.6456 - learning_rate: 0.0010
# Epoch 8/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5774 - loss: 0.8228 - val_accuracy: 0.6225 - val_loss: 0.6648 - learning_rate: 0.0010
# Epoch 9/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5737 - loss: 0.8079 - val_accuracy: 0.6644 - val_loss: 0.6286 - learning_rate: 0.0010
# Epoch 10/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5819 - loss: 0.7971 - val_accuracy: 0.6171 - val_loss: 0.6831 - learning_rate: 0.0010
# Epoch 11/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5674 - loss: 0.7875 - val_accuracy: 0.6346 - val_loss: 0.6317 - learning_rate: 0.0010
# Epoch 12/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5859 - loss: 0.7789 - val_accuracy: 0.6712 - val_loss: 0.6154 - learning_rate: 0.0010
# Epoch 13/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5832 - loss: 0.8053 - val_accuracy: 0.6346 - val_loss: 0.6983 - learning_rate: 0.0010
# Epoch 14/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5840 - loss: 0.7482 - val_accuracy: 0.6225 - val_loss: 0.6413 - learning_rate: 0.0010
# Epoch 15/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5817 - loss: 0.7430 - val_accuracy: 0.6238 - val_loss: 0.6608 - learning_rate: 0.0010
# Epoch 16/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5859 - loss: 0.7923 - val_accuracy: 0.6752 - val_loss: 0.6177 - learning_rate: 0.0010
# Epoch 17/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5973 - loss: 0.7425 - val_accuracy: 0.6103 - val_loss: 0.6538 - learning_rate: 0.0010
# Epoch 18/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5872 - loss: 0.7346 - val_accuracy: 0.6752 - val_loss: 0.6177 - learning_rate: 0.0010
# Epoch 19/50
# 69/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6059 - loss: 0.7090
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6016 - loss: 0.7175 - val_accuracy: 0.5250 - val_loss: 0.6960 - learning_rate: 0.0010
# Epoch 20/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6082 - loss: 0.6749 - val_accuracy: 0.6739 - val_loss: 0.6210 - learning_rate: 1.0000e-04
# Epoch 21/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6572 - loss: 0.6263 - val_accuracy: 0.6752 - val_loss: 0.6229 - learning_rate: 1.0000e-04
# Epoch 22/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6513 - loss: 0.6206 - val_accuracy: 0.6509 - val_loss: 0.6287 - learning_rate: 1.0000e-04
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 12.
# Model 3_4 - Test Loss: 0.6154, Test Accuracy: 0.6712
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#
# Confusion Matrix:
# [[ 98 192]
#  [ 51 398]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         high       0.66      0.34      0.45       290
#          low       0.67      0.89      0.77       449
#
#     accuracy                           0.67       739
#    macro avg       0.67      0.61      0.61       739
# weighted avg       0.67      0.67      0.64       739

# %% [markdown]
# ## **Model 3_5:** add dropout, but with original model3

# %%
# -------------------------- Model 3_5 -----------------------------------
# Specify Model 3_5:
model3_5 = Sequential([
    Input(shape=(X_train.shape[1],)),
    Dense(200, activation='relu'),
    Dropout(0.3),
    Dense(2, activation='softmax')
])

# Compile the model
model3_5.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train Model 3_5
model3_5_training = model3_5.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=30,
    callbacks=[early_stopping_monitor],
    shuffle=False,
    verbose=1
)

# Evaluate Model 3_5
test_loss3_5, test_accuracy3_5 = model3_5.evaluate(X_test, y_test, verbose=0)
print(f"Model 3_5 - Test Loss: {test_loss3_5:.4f}, Test Accuracy: {test_accuracy3_5:.4f}")

# Get confusion matrix and classification metrics
from sklearn.metrics import confusion_matrix, classification_report

# Predict on test set
y_pred3_5 = model3_5.predict(X_test)
y_pred3_5_classes = y_pred3_5.argmax(axis=1)
y_test_classes = y_test.argmax(axis=1)

# Compute confusion matrix
conf_matrix3_5 = confusion_matrix(y_test_classes, y_pred3_5_classes)
print("\nConfusion Matrix:")
print(conf_matrix3_5)

# Compute classification report
class_report3_5 = classification_report(y_test_classes, y_pred3_5_classes, target_names=label_encoder.classes_)
print("\nClassification Report:")
print(class_report3_5)
# Out:
# Epoch 1/30
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5538 - loss: 45.8518 - val_accuracy: 0.4317 - val_loss: 7.7591
# Epoch 2/30
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5231 - loss: 22.7189 - val_accuracy: 0.6279 - val_loss: 4.4615
# Epoch 3/30
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5470 - loss: 11.8228 - val_accuracy: 0.6157 - val_loss: 4.9881
# Model 3_5 - Test Loss: 7.7591, Test Accuracy: 0.4317
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#
# Confusion Matrix:
# [[274  16]
#  [404  45]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         high       0.40      0.94      0.57       290
#          low       0.74      0.10      0.18       449
#
#     accuracy                           0.43       739
#    macro avg       0.57      0.52      0.37       739
# weighted avg       0.61      0.43      0.33       739

# %% [markdown]
# ## **Model 3_6:** increase epochs

# %%
# -------------------------- Model 3_6 -----------------------------------
# Specify Model 3_6: Increase epochs for training
model3_6 = Sequential([
    Input(shape=(X_train.shape[1],)),
    Dense(200, activation='relu'),
    Dense(2, activation='softmax')
])

# Compile the model
model3_6.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Define EarlyStopping callback (reuse or redefine if needed)
early_stopping_monitor_3_6 = EarlyStopping(
    patience=10,  # Patience for early stopping
    restore_best_weights=True,
    verbose=1
)

# Train Model 3_6 with increased epochs
model3_6_training = model3_6.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=50,  # Increased number of epochs
    callbacks=[early_stopping_monitor_3_6],
    shuffle=False,
    verbose=1
)

# Evaluate Model 3_6
test_loss3_6, test_accuracy3_6 = model3_6.evaluate(X_test, y_test, verbose=0)
print(f"Model 3_6 - Test Loss: {test_loss3_6:.4f}, Test Accuracy: {test_accuracy3_6:.4f}")
# Out:
# Epoch 1/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5327 - loss: 3.6185 - val_accuracy: 0.6184 - val_loss: 0.6782
# Epoch 2/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5887 - loss: 1.1159 - val_accuracy: 0.6482 - val_loss: 0.6287
# Epoch 3/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6013 - loss: 0.8795 - val_accuracy: 0.5467 - val_loss: 0.7448
# Epoch 4/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6106 - loss: 0.9510 - val_accuracy: 0.5318 - val_loss: 0.7971
# Epoch 5/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5729 - loss: 1.5222 - val_accuracy: 0.6468 - val_loss: 0.6411
# Epoch 6/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6318 - loss: 0.8466 - val_accuracy: 0.6143 - val_loss: 2.3174
# Epoch 7/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5546 - loss: 1.9369 - val_accuracy: 0.6022 - val_loss: 0.6963
# Epoch 8/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6607 - loss: 0.7853 - val_accuracy: 0.6942 - val_loss: 0.6219
# Epoch 9/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6650 - loss: 0.7179 - val_accuracy: 0.6671 - val_loss: 0.6187
# Epoch 10/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6380 - loss: 0.8143 - val_accuracy: 0.6874 - val_loss: 0.6245
# Epoch 11/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6476 - loss: 0.7308 - val_accuracy: 0.6861 - val_loss: 0.6472
# Epoch 12/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6525 - loss: 0.7924 - val_accuracy: 0.6049 - val_loss: 0.6753
# Epoch 13/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6512 - loss: 0.7418 - val_accuracy: 0.6658 - val_loss: 0.7248
# Epoch 14/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6375 - loss: 0.7956 - val_accuracy: 0.6604 - val_loss: 0.6276
# Epoch 15/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6619 - loss: 0.7319 - val_accuracy: 0.6414 - val_loss: 0.8178
# Epoch 16/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6254 - loss: 1.1402 - val_accuracy: 0.6035 - val_loss: 0.7247
# Epoch 17/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6026 - loss: 1.1984 - val_accuracy: 0.4127 - val_loss: 1.6894
# Epoch 18/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6014 - loss: 1.1073 - val_accuracy: 0.6982 - val_loss: 0.6159
# Epoch 19/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6699 - loss: 0.7941 - val_accuracy: 0.4208 - val_loss: 1.4274
# Epoch 20/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5914 - loss: 1.0759 - val_accuracy: 0.6008 - val_loss: 0.7210
# Epoch 21/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6579 - loss: 0.8231 - val_accuracy: 0.6346 - val_loss: 0.6396
# Epoch 22/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6653 - loss: 0.7604 - val_accuracy: 0.6103 - val_loss: 0.6828
# Epoch 23/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6480 - loss: 0.7935 - val_accuracy: 0.6252 - val_loss: 0.6410
# Epoch 24/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6447 - loss: 0.8232 - val_accuracy: 0.6455 - val_loss: 0.6310
# Epoch 25/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6417 - loss: 0.8776 - val_accuracy: 0.6820 - val_loss: 0.6412
# Epoch 26/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6586 - loss: 0.7134 - val_accuracy: 0.6942 - val_loss: 0.6130
# Epoch 27/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6588 - loss: 0.7279 - val_accuracy: 0.6901 - val_loss: 0.6214
# Epoch 28/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6647 - loss: 0.7349 - val_accuracy: 0.6861 - val_loss: 0.6363
# Epoch 29/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6628 - loss: 0.7433 - val_accuracy: 0.6211 - val_loss: 0.6468
# Epoch 30/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6255 - loss: 1.2064 - val_accuracy: 0.6401 - val_loss: 1.0597
# Epoch 31/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6006 - loss: 1.1800 - val_accuracy: 0.6238 - val_loss: 0.6748
# Epoch 32/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6594 - loss: 0.7642 - val_accuracy: 0.6238 - val_loss: 0.6406
# Epoch 33/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6521 - loss: 0.7774 - val_accuracy: 0.6644 - val_loss: 0.6140
# Epoch 34/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6513 - loss: 0.7796 - val_accuracy: 0.6820 - val_loss: 0.6166
# Epoch 35/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6570 - loss: 0.7172 - val_accuracy: 0.6955 - val_loss: 0.5999
# Epoch 36/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6558 - loss: 0.7350 - val_accuracy: 0.6901 - val_loss: 0.6077
# Epoch 37/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6552 - loss: 0.7309 - val_accuracy: 0.6915 - val_loss: 0.6223
# Epoch 38/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6641 - loss: 0.7284 - val_accuracy: 0.6834 - val_loss: 0.6419
# Epoch 39/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6651 - loss: 0.7402 - val_accuracy: 0.6834 - val_loss: 0.6279
# Epoch 40/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6629 - loss: 0.7382 - val_accuracy: 0.6752 - val_loss: 0.6643
# Epoch 41/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6501 - loss: 0.8468 - val_accuracy: 0.5129 - val_loss: 0.9126
# Epoch 42/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6443 - loss: 0.8478 - val_accuracy: 0.6793 - val_loss: 0.5983
# Epoch 43/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6525 - loss: 0.7608 - val_accuracy: 0.6874 - val_loss: 0.6019
# Epoch 44/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6526 - loss: 0.7704 - val_accuracy: 0.6874 - val_loss: 0.6016
# Epoch 45/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6513 - loss: 0.8261 - val_accuracy: 0.6982 - val_loss: 0.6047
# Epoch 46/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6634 - loss: 0.7096 - val_accuracy: 0.6901 - val_loss: 0.6024
# Epoch 47/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6577 - loss: 0.7529 - val_accuracy: 0.6901 - val_loss: 0.5989
# Epoch 48/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6588 - loss: 0.7477 - val_accuracy: 0.6915 - val_loss: 0.6202
# Epoch 49/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6664 - loss: 0.7232 - val_accuracy: 0.6820 - val_loss: 0.6386
# Epoch 50/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6693 - loss: 0.7274 - val_accuracy: 0.6766 - val_loss: 0.6491
# Restoring model weights from the end of the best epoch: 42.
# Model 3_6 - Test Loss: 0.5983, Test Accuracy: 0.6793

# %% [markdown]
# ## **Model3_7:** increase epochs in model3_3

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# -------------------------- Model 3_7 -----------------------------------
# Specify Model 3_7: Same architecture as Model 3_3
model3_7 = Sequential([
    Input(shape=(X_train.shape[1],)),
    Dense(200, activation='relu'),
    Dense(2, activation='softmax')
])

# Compile the model
model3_7.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Define callbacks with increased patience
early_stopping_monitor_3_7 = EarlyStopping(
    patience=10,  # Same patience as in Model 3_3
    restore_best_weights=True,
    verbose=1
)

reduce_lr_3_7 = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.1,
    patience=7,  # Same patience as in Model 3_3
    min_lr=1e-6,
    verbose=1
)

# Train Model 3_7 with increased epochs
model3_7_training = model3_7.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=100,  # Increased number of epochs
    callbacks=[early_stopping_monitor_3_7, reduce_lr_3_7],
    shuffle=False,
    verbose=1
)

# Evaluate Model 3_7
test_loss3_7, test_accuracy3_7 = model3_7.evaluate(X_test, y_test, verbose=0)
print(f"Model 3_7 - Test Loss: {test_loss3_7:.4f}, Test Accuracy: {test_accuracy3_7:.4f}")
# Out:
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.5212 - loss: 6.7944 - val_accuracy: 0.6062 - val_loss: 0.7758 - learning_rate: 0.0010
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5739 - loss: 0.9555 - val_accuracy: 0.4046 - val_loss: 1.4175 - learning_rate: 0.0010
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5804 - loss: 0.9780 - val_accuracy: 0.6116 - val_loss: 1.6979 - learning_rate: 0.0010
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5502 - loss: 2.2449 - val_accuracy: 0.6252 - val_loss: 0.7748 - learning_rate: 0.0010
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6085 - loss: 1.2276 - val_accuracy: 0.4574 - val_loss: 1.2732 - learning_rate: 0.0010
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6007 - loss: 1.0836 - val_accuracy: 0.6955 - val_loss: 0.6168 - learning_rate: 0.0010
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6652 - loss: 0.7924 - val_accuracy: 0.6752 - val_loss: 0.6207 - learning_rate: 0.0010
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6445 - loss: 0.9034 - val_accuracy: 0.6482 - val_loss: 0.6978 - learning_rate: 0.0010
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6379 - loss: 0.8939 - val_accuracy: 0.6211 - val_loss: 0.7001 - learning_rate: 0.0010
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6487 - loss: 0.8439 - val_accuracy: 0.6346 - val_loss: 0.6630 - learning_rate: 0.0010
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6646 - loss: 0.7285 - val_accuracy: 0.6590 - val_loss: 0.8118 - learning_rate: 0.0010
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6418 - loss: 0.8298 - val_accuracy: 0.6752 - val_loss: 0.7108 - learning_rate: 0.0010
# Epoch 13/100
# 66/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6580 - loss: 0.7737
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6427 - loss: 0.8794 - val_accuracy: 0.3924 - val_loss: 2.5155 - learning_rate: 0.0010
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6065 - loss: 1.0352 - val_accuracy: 0.6874 - val_loss: 0.6076 - learning_rate: 1.0000e-04
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7085 - loss: 0.6006 - val_accuracy: 0.7037 - val_loss: 0.6065 - learning_rate: 1.0000e-04
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7012 - loss: 0.6026 - val_accuracy: 0.6915 - val_loss: 0.6117 - learning_rate: 1.0000e-04
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6963 - loss: 0.6050 - val_accuracy: 0.6942 - val_loss: 0.6199 - learning_rate: 1.0000e-04
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6977 - loss: 0.6071 - val_accuracy: 0.6996 - val_loss: 0.6283 - learning_rate: 1.0000e-04
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6967 - loss: 0.6077 - val_accuracy: 0.6996 - val_loss: 0.6328 - learning_rate: 1.0000e-04
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6936 - loss: 0.6068 - val_accuracy: 0.6942 - val_loss: 0.6332 - learning_rate: 1.0000e-04
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6915 - loss: 0.6053 - val_accuracy: 0.6942 - val_loss: 0.6308 - learning_rate: 1.0000e-04
# Epoch 22/100
# 68/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6968 - loss: 0.5937
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6899 - loss: 0.6041 - val_accuracy: 0.6942 - val_loss: 0.6307 - learning_rate: 1.0000e-04
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7115 - loss: 0.5788 - val_accuracy: 0.6915 - val_loss: 0.6034 - learning_rate: 1.0000e-05
# Epoch 24/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7062 - loss: 0.5735 - val_accuracy: 0.6928 - val_loss: 0.6028 - learning_rate: 1.0000e-05
# Epoch 25/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7059 - loss: 0.5735 - val_accuracy: 0.6928 - val_loss: 0.6026 - learning_rate: 1.0000e-05
# Epoch 26/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7073 - loss: 0.5735 - val_accuracy: 0.6928 - val_loss: 0.6025 - learning_rate: 1.0000e-05
# Epoch 27/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7070 - loss: 0.5735 - val_accuracy: 0.6928 - val_loss: 0.6024 - learning_rate: 1.0000e-05
# Epoch 28/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7067 - loss: 0.5735 - val_accuracy: 0.6928 - val_loss: 0.6023 - learning_rate: 1.0000e-05
# Epoch 29/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7061 - loss: 0.5735 - val_accuracy: 0.6915 - val_loss: 0.6023 - learning_rate: 1.0000e-05
# Epoch 30/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7057 - loss: 0.5735 - val_accuracy: 0.6915 - val_loss: 0.6023 - learning_rate: 1.0000e-05
# Epoch 31/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7052 - loss: 0.5736 - val_accuracy: 0.6861 - val_loss: 0.6025 - learning_rate: 1.0000e-05
# Epoch 32/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7055 - loss: 0.5737 - val_accuracy: 0.6861 - val_loss: 0.6027 - learning_rate: 1.0000e-05
# Epoch 33/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7051 - loss: 0.5739 - val_accuracy: 0.6874 - val_loss: 0.6030 - learning_rate: 1.0000e-05
# Epoch 34/100
# 90/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7044 - loss: 0.5729
# Epoch 34: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7039 - loss: 0.5740 - val_accuracy: 0.6847 - val_loss: 0.6034 - learning_rate: 1.0000e-05
# Epoch 35/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7041 - loss: 0.5728 - val_accuracy: 0.6888 - val_loss: 0.5994 - learning_rate: 1.0000e-06
# Epoch 36/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7121 - loss: 0.5698 - val_accuracy: 0.6901 - val_loss: 0.5994 - learning_rate: 1.0000e-06
# Epoch 37/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7121 - loss: 0.5698 - val_accuracy: 0.6901 - val_loss: 0.5994 - learning_rate: 1.0000e-06
# Epoch 38/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7121 - loss: 0.5698 - val_accuracy: 0.6901 - val_loss: 0.5994 - learning_rate: 1.0000e-06
# Epoch 39/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7124 - loss: 0.5698 - val_accuracy: 0.6901 - val_loss: 0.5994 - learning_rate: 1.0000e-06
# Epoch 40/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7124 - loss: 0.5698 - val_accuracy: 0.6901 - val_loss: 0.5994 - learning_rate: 1.0000e-06
# Epoch 41/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7123 - loss: 0.5698 - val_accuracy: 0.6901 - val_loss: 0.5994 - learning_rate: 1.0000e-06
# Epoch 42/100
# 79/93 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7140 - loss: 0.5657
# Epoch 42: ReduceLROnPlateau reducing learning rate to 1e-06.
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7123 - loss: 0.5698 - val_accuracy: 0.6901 - val_loss: 0.5994 - learning_rate: 1.0000e-06
# Epoch 43/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7123 - loss: 0.5698 - val_accuracy: 0.6915 - val_loss: 0.5994 - learning_rate: 1.0000e-06
# Epoch 44/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7123 - loss: 0.5698 - val_accuracy: 0.6901 - val_loss: 0.5994 - learning_rate: 1.0000e-06
# Epoch 45/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7123 - loss: 0.5698 - val_accuracy: 0.6901 - val_loss: 0.5994 - learning_rate: 1.0000e-06
# Epoch 45: early stopping
# Restoring model weights from the end of the best epoch: 35.
# Model 3_7 - Test Loss: 0.5994, Test Accuracy: 0.6888

# %% [markdown]
# ## **Model3_8:** add resampling technique

# %%
from sklearn.utils import resample
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.callbacks import EarlyStopping

# Resampling the training data
# Assuming y_train is not one-hot encoded initially
X_train_resampled, y_train_resampled = resample(
    X_train, y_train, replace=True, n_samples=len(X_train), random_state=42
)

# Check if `y_train` is already one-hot encoded; if not, apply one-hot encoding
if len(y_train_resampled.shape) == 1 or y_train_resampled.shape[1] == 1:
    y_train_resampled_onehot = to_categorical(y_train_resampled, num_classes=2)
else:
    y_train_resampled_onehot = y_train_resampled

# Debugging shapes
print(f"X_train_resampled shape: {X_train_resampled.shape}")
print(f"y_train_resampled shape: {y_train_resampled.shape}")
print(f"y_train_resampled_onehot shape: {y_train_resampled_onehot.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"y_test shape: {y_test.shape}")

# -------------------------- Model 3_8 -----------------------------------
# Specify Model 3_8: Hidden layer = 1, Dense = 200
model3_8 = Sequential([
    Input(shape=(X_train.shape[1],)),
    Dense(200, activation='relu'),
    Dense(2, activation='softmax')
])

# Compile the model
model3_8.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Define EarlyStopping callback
early_stopping_monitor_3_8 = EarlyStopping(
    patience=5,
    restore_best_weights=True,
    verbose=1
)

# Train Model 3_8
model3_8_training = model3_8.fit(
    X_train_resampled, y_train_resampled_onehot,
    validation_data=(X_test, y_test),  # Ensure y_test is already one-hot encoded
    epochs=30,
    callbacks=[early_stopping_monitor_3_8],
    shuffle=True,
    verbose=1
)

# Evaluate Model 3_8
test_loss3_8, test_accuracy3_8 = model3_8.evaluate(X_test, y_test, verbose=0)
print(f"Model 3_8 - Test Loss: {test_loss3_8:.4f}, Test Accuracy: {test_accuracy3_8:.4f}")

# Generate predictions and calculate confusion matrix
y_pred_probs = model3_8.predict(X_test)
y_pred_classes = y_pred_probs.argmax(axis=1)

from sklearn.metrics import confusion_matrix, classification_report

# Assuming y_test is one-hot encoded; get the class labels
y_test_classes = y_test.argmax(axis=1)

conf_matrix = confusion_matrix(y_test_classes, y_pred_classes)
class_report = classification_report(y_test_classes, y_pred_classes, target_names=['high', 'low'])

print("\nConfusion Matrix:")
print(conf_matrix)
print("\nClassification Report:")
print(class_report)
# Out:
# X_train_resampled shape: (2953, 11)
# y_train_resampled shape: (2953, 2)
# y_train_resampled_onehot shape: (2953, 2)
# X_test shape: (739, 11)
# y_test shape: (739, 2)
# Epoch 1/30
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5448 - loss: 11.2649 - val_accuracy: 0.3951 - val_loss: 2.8383
# Epoch 2/30
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5420 - loss: 1.5628 - val_accuracy: 0.3924 - val_loss: 4.2514
# Epoch 3/30
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5522 - loss: 2.5616 - val_accuracy: 0.3924 - val_loss: 2.9724
# Epoch 4/30
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5776 - loss: 1.3825 - val_accuracy: 0.5589 - val_loss: 0.9678
# Epoch 5/30
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6014 - loss: 0.9742 - val_accuracy: 0.3924 - val_loss: 3.7681
# Epoch 6/30
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5788 - loss: 1.7137 - val_accuracy: 0.6793 - val_loss: 0.8142
# Epoch 7/30
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6000 - loss: 1.0653 - val_accuracy: 0.5629 - val_loss: 0.9967
# Epoch 8/30
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6101 - loss: 0.9874 - val_accuracy: 0.6211 - val_loss: 0.7835
# Epoch 9/30
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5887 - loss: 1.4685 - val_accuracy: 0.5359 - val_loss: 1.0360
# Epoch 10/30
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6087 - loss: 0.9057 - val_accuracy: 0.6874 - val_loss: 0.6750
# Epoch 11/30
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6028 - loss: 0.9814 - val_accuracy: 0.6928 - val_loss: 0.6824
# Epoch 12/30
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6064 - loss: 1.0199 - val_accuracy: 0.3924 - val_loss: 4.0223
# Epoch 13/30
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5755 - loss: 1.6532 - val_accuracy: 0.4398 - val_loss: 1.5691
# Epoch 14/30
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6070 - loss: 1.1393 - val_accuracy: 0.4290 - val_loss: 1.7006
# Epoch 15/30
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5779 - loss: 1.3182 - val_accuracy: 0.4520 - val_loss: 1.3798
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 10.
# Model 3_8 - Test Loss: 0.6750, Test Accuracy: 0.6874
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#
# Confusion Matrix:
# [[144 146]
#  [ 85 364]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         high       0.63      0.50      0.55       290
#          low       0.71      0.81      0.76       449
#
#     accuracy                           0.69       739
#    macro avg       0.67      0.65      0.66       739
# weighted avg       0.68      0.69      0.68       739

# %% [markdown]
# # **Select model3_3 for hyperparameter tuning**

# %%
# !pip install keras-tuner --quiet

# %%
import keras_tuner as kt
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input

# Define the model-building function
def build_model(hp):
    model = Sequential([
        Input(shape=(X_train.shape[1],)),  # Input layer
        Dense(hp.Int("units", min_value=100, max_value=400, step=50), activation='relu'),  # Dense layer with tunable units
        Dense(2, activation="softmax")  # Output layer
    ])
    model.compile(
        optimizer=Adam(learning_rate=hp.Choice("learning_rate", values=[1e-4, 1e-3, 1e-2])),
        loss="categorical_crossentropy",
        metrics=["accuracy"]
    )
    return model

# Define the tuner
tuner = kt.Hyperband(
    build_model,
    objective="val_accuracy",
    max_epochs=50,  # Increased epochs for better convergence
    factor=3,
    directory="my_dir",
    project_name="model3_3_tuning"
)

# Define callbacks for early stopping and learning rate reduction
early_stopping_monitor = EarlyStopping(
    patience=10,  # Stop if validation loss doesn't improve for 10 epochs
    restore_best_weights=True,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.1,
    patience=7,
    min_lr=1e-6,
    verbose=1
)

# Run the hyperparameter search
tuner.search(
    X_train, y_train,
    validation_data=(X_test, y_test),
    callbacks=[early_stopping_monitor, reduce_lr],
    shuffle=True
)

# Display the best hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
print(f"""
The optimal number of units is {best_hps.get('units')}
and the optimal learning rate is {best_hps.get('learning_rate')}.
""")

# Build the model with the best hyperparameters
best_model = tuner.hypermodel.build(best_hps)

# Train the best model
history = best_model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=50,
    callbacks=[early_stopping_monitor, reduce_lr],
    shuffle=True,
    verbose=1
)

# Evaluate the best model
test_loss, test_accuracy = best_model.evaluate(X_test, y_test, verbose=0)
print(f"Best Model - Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")
# Out:
# Reloading Tuner from my_dir/model3_3_tuning/tuner0.json
#
# The optimal number of units is 300
# and the optimal learning rate is 0.0001.
#
# Epoch 1/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.5739 - loss: 22.1697 - val_accuracy: 0.5737 - val_loss: 2.7737 - learning_rate: 1.0000e-04
# Epoch 2/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5734 - loss: 2.4711 - val_accuracy: 0.5440 - val_loss: 1.9323 - learning_rate: 1.0000e-04
# Epoch 3/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5710 - loss: 1.7267 - val_accuracy: 0.4966 - val_loss: 1.7823 - learning_rate: 1.0000e-04
# Epoch 4/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5890 - loss: 1.3940 - val_accuracy: 0.5345 - val_loss: 1.3352 - learning_rate: 1.0000e-04
# Epoch 5/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5845 - loss: 1.1791 - val_accuracy: 0.4899 - val_loss: 1.2805 - learning_rate: 1.0000e-04
# Epoch 6/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5949 - loss: 1.0549 - val_accuracy: 0.4750 - val_loss: 1.2255 - learning_rate: 1.0000e-04
# Epoch 7/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6155 - loss: 0.9258 - val_accuracy: 0.5034 - val_loss: 1.0307 - learning_rate: 1.0000e-04
# Epoch 8/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6330 - loss: 0.8049 - val_accuracy: 0.5832 - val_loss: 0.7968 - learning_rate: 1.0000e-04
# Epoch 9/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6437 - loss: 0.7458 - val_accuracy: 0.6022 - val_loss: 0.7369 - learning_rate: 1.0000e-04
# Epoch 10/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6504 - loss: 0.7162 - val_accuracy: 0.6035 - val_loss: 0.7133 - learning_rate: 1.0000e-04
# Epoch 11/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.6501 - loss: 0.6948 - val_accuracy: 0.6089 - val_loss: 0.6981 - learning_rate: 1.0000e-04
# Epoch 12/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6516 - loss: 0.6807 - val_accuracy: 0.6211 - val_loss: 0.6832 - learning_rate: 1.0000e-04
# Epoch 13/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6506 - loss: 0.6711 - val_accuracy: 0.6238 - val_loss: 0.6690 - learning_rate: 1.0000e-04
# Epoch 14/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6577 - loss: 0.6643 - val_accuracy: 0.6455 - val_loss: 0.6556 - learning_rate: 1.0000e-04
# Epoch 15/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6576 - loss: 0.6603 - val_accuracy: 0.6441 - val_loss: 0.6438 - learning_rate: 1.0000e-04
# Epoch 16/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6592 - loss: 0.6574 - val_accuracy: 0.6522 - val_loss: 0.6336 - learning_rate: 1.0000e-04
# Epoch 17/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6552 - loss: 0.6554 - val_accuracy: 0.6617 - val_loss: 0.6271 - learning_rate: 1.0000e-04
# Epoch 18/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6562 - loss: 0.6545 - val_accuracy: 0.6685 - val_loss: 0.6214 - learning_rate: 1.0000e-04
# Epoch 19/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6590 - loss: 0.6536 - val_accuracy: 0.6658 - val_loss: 0.6175 - learning_rate: 1.0000e-04
# Epoch 20/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6568 - loss: 0.6528 - val_accuracy: 0.6698 - val_loss: 0.6139 - learning_rate: 1.0000e-04
# Epoch 21/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6552 - loss: 0.6519 - val_accuracy: 0.6739 - val_loss: 0.6111 - learning_rate: 1.0000e-04
# Epoch 22/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6572 - loss: 0.6509 - val_accuracy: 0.6712 - val_loss: 0.6088 - learning_rate: 1.0000e-04
# Epoch 23/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6553 - loss: 0.6503 - val_accuracy: 0.6685 - val_loss: 0.6069 - learning_rate: 1.0000e-04
# Epoch 24/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6522 - loss: 0.6496 - val_accuracy: 0.6671 - val_loss: 0.6057 - learning_rate: 1.0000e-04
# Epoch 25/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6493 - loss: 0.6485 - val_accuracy: 0.6712 - val_loss: 0.6046 - learning_rate: 1.0000e-04
# Epoch 26/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6455 - loss: 0.6480 - val_accuracy: 0.6712 - val_loss: 0.6035 - learning_rate: 1.0000e-04
# Epoch 27/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.6444 - loss: 0.6478 - val_accuracy: 0.6685 - val_loss: 0.6028 - learning_rate: 1.0000e-04
# Epoch 28/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6435 - loss: 0.6475 - val_accuracy: 0.6698 - val_loss: 0.6020 - learning_rate: 1.0000e-04
# Epoch 29/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6438 - loss: 0.6474 - val_accuracy: 0.6698 - val_loss: 0.6017 - learning_rate: 1.0000e-04
# Epoch 30/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6446 - loss: 0.6471 - val_accuracy: 0.6685 - val_loss: 0.6015 - learning_rate: 1.0000e-04
# Epoch 31/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6463 - loss: 0.6468 - val_accuracy: 0.6685 - val_loss: 0.6010 - learning_rate: 1.0000e-04
# Epoch 32/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6470 - loss: 0.6464 - val_accuracy: 0.6658 - val_loss: 0.6010 - learning_rate: 1.0000e-04
# Epoch 33/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6480 - loss: 0.6460 - val_accuracy: 0.6671 - val_loss: 0.6013 - learning_rate: 1.0000e-04
# Epoch 34/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6493 - loss: 0.6458 - val_accuracy: 0.6658 - val_loss: 0.6015 - learning_rate: 1.0000e-04
# Epoch 35/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6464 - loss: 0.6456 - val_accuracy: 0.6671 - val_loss: 0.6015 - learning_rate: 1.0000e-04
# Epoch 36/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6463 - loss: 0.6455 - val_accuracy: 0.6671 - val_loss: 0.6019 - learning_rate: 1.0000e-04
# Epoch 37/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6449 - loss: 0.6453 - val_accuracy: 0.6658 - val_loss: 0.6024 - learning_rate: 1.0000e-04
# Epoch 38/50
# 76/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6420 - loss: 0.6473
# Epoch 38: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6462 - loss: 0.6450 - val_accuracy: 0.6671 - val_loss: 0.6032 - learning_rate: 1.0000e-04
# Epoch 39/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6788 - loss: 0.6003 - val_accuracy: 0.6915 - val_loss: 0.5905 - learning_rate: 1.0000e-05
# Epoch 40/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6708 - loss: 0.6044 - val_accuracy: 0.6942 - val_loss: 0.5907 - learning_rate: 1.0000e-05
# Epoch 41/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6722 - loss: 0.6045 - val_accuracy: 0.6942 - val_loss: 0.5907 - learning_rate: 1.0000e-05
# Epoch 42/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6706 - loss: 0.6046 - val_accuracy: 0.6928 - val_loss: 0.5906 - learning_rate: 1.0000e-05
# Epoch 43/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6709 - loss: 0.6047 - val_accuracy: 0.6901 - val_loss: 0.5907 - learning_rate: 1.0000e-05
# Epoch 44/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6708 - loss: 0.6048 - val_accuracy: 0.6915 - val_loss: 0.5907 - learning_rate: 1.0000e-05
# Epoch 45/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6727 - loss: 0.6050 - val_accuracy: 0.6901 - val_loss: 0.5908 - learning_rate: 1.0000e-05
# Epoch 46/50
# 78/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6693 - loss: 0.6082
# Epoch 46: ReduceLROnPlateau reducing learning rate to 1e-06.
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6726 - loss: 0.6052 - val_accuracy: 0.6901 - val_loss: 0.5909 - learning_rate: 1.0000e-05
# Epoch 47/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6754 - loss: 0.5989 - val_accuracy: 0.6820 - val_loss: 0.5919 - learning_rate: 1.0000e-06
# Epoch 48/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6767 - loss: 0.5992 - val_accuracy: 0.6847 - val_loss: 0.5915 - learning_rate: 1.0000e-06
# Epoch 49/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6768 - loss: 0.5989 - val_accuracy: 0.6861 - val_loss: 0.5912 - learning_rate: 1.0000e-06
# Epoch 49: early stopping
# Restoring model weights from the end of the best epoch: 39.
# Best Model - Test Loss: 0.5905, Test Accuracy: 0.6915

# %% [markdown]
# ## **Model3_10:** Assigning class weights during model training

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

# -------------------- Ensure Proper One-Hot Encoding --------------------
# If y_train is already one-hot encoded, keep it as is
if y_train.ndim == 2 and y_train.shape[1] == 2:
    y_train_onehot = y_train  # Already one-hot encoded
else:
    y_train_onehot = to_categorical(y_train, num_classes=2)

# Ensure y_test is one-hot encoded
if y_test.ndim == 2 and y_test.shape[1] == 2:
    y_test_onehot = y_test  # Already one-hot encoded
else:
    y_test_onehot = to_categorical(y_test[:X_test.shape[0]], num_classes=2)  # Match X_test size

# Debug shapes
print(f"X_train shape: {X_train.shape}")
print(f"y_train_onehot shape: {y_train_onehot.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"y_test_onehot shape: {y_test_onehot.shape}")

# Ensure dimensions match
assert X_train.shape[0] == y_train_onehot.shape[0], (
    f"Mismatch: X_train has {X_train.shape[0]} samples, "
    f"y_train_onehot has {y_train_onehot.shape[0]} samples."
)
assert X_test.shape[0] == y_test_onehot.shape[0], (
    f"Mismatch: X_test has {X_test.shape[0]} samples, "
    f"y_test_onehot has {y_test_onehot.shape[0]} samples."
)

# -------------------- Calculate Class Weights --------------------
# Compute class weights
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train.flatten() if y_train.ndim > 1 else y_train),
    y=y_train.flatten() if y_train.ndim > 1 else y_train
)

# Convert class weights to a dictionary
class_weights_dict = {i: weight for i, weight in enumerate(class_weights)}
print(f"Class Weights: {class_weights_dict}")

# -------------------- Model 3_10 Architecture --------------------
model_3_10 = Sequential([
    Input(shape=(X_train.shape[1],)),
    Dense(200, activation='relu'),
    Dense(2, activation='softmax')
])

# Compile the model
model_3_10.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Define callbacks
early_stopping = EarlyStopping(
    patience=15, restore_best_weights=True, verbose=1
)
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.1,
    patience=5,
    min_lr=1e-6,
    verbose=1
)

# -------------------- Train Model 3_10 --------------------
model_3_10_training = model_3_10.fit(
    X_train, y_train_onehot,  # Use one-hot encoded data
    validation_data=(X_test, y_test_onehot),  # Use correctly encoded test data
    epochs=50,
    class_weight=class_weights_dict,
    callbacks=[early_stopping, reduce_lr],
    verbose=1
)

# Evaluate the model
test_loss_3_10, test_accuracy_3_10 = model_3_10.evaluate(X_test, y_test_onehot, verbose=0)
print(f"Model 3_10 - Test Loss: {test_loss_3_10:.4f}, Test Accuracy: {test_accuracy_3_10:.4f}")
# Out:
# X_train shape: (2953, 11)
# y_train_onehot shape: (2953, 2)
# X_test shape: (739, 11)
# y_test_onehot shape: (739, 2)
# Class Weights: {0: 1.0, 1: 1.0}
# Epoch 1/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.5528 - loss: 11.3070 - val_accuracy: 0.6698 - val_loss: 1.1116 - learning_rate: 0.0010
# Epoch 2/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5976 - loss: 1.2693 - val_accuracy: 0.4127 - val_loss: 1.9127 - learning_rate: 0.0010
# Epoch 3/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5684 - loss: 1.3799 - val_accuracy: 0.3951 - val_loss: 2.3082 - learning_rate: 0.0010
# Epoch 4/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5643 - loss: 1.3524 - val_accuracy: 0.3978 - val_loss: 2.1079 - learning_rate: 0.0010
# Epoch 5/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5811 - loss: 1.2740 - val_accuracy: 0.3992 - val_loss: 2.1109 - learning_rate: 0.0010
# Epoch 6/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5746 - loss: 1.2782
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5748 - loss: 1.2763 - val_accuracy: 0.3992 - val_loss: 2.1267 - learning_rate: 0.0010
# Epoch 7/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5982 - loss: 0.9551 - val_accuracy: 0.6333 - val_loss: 0.7171 - learning_rate: 1.0000e-04
# Epoch 8/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6519 - loss: 0.6852 - val_accuracy: 0.6143 - val_loss: 0.7262 - learning_rate: 1.0000e-04
# Epoch 9/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6476 - loss: 0.6761 - val_accuracy: 0.6306 - val_loss: 0.7064 - learning_rate: 1.0000e-04
# Epoch 10/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6562 - loss: 0.6671 - val_accuracy: 0.6360 - val_loss: 0.6933 - learning_rate: 1.0000e-04
# Epoch 11/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6554 - loss: 0.6627 - val_accuracy: 0.6373 - val_loss: 0.6856 - learning_rate: 1.0000e-04
# Epoch 12/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6534 - loss: 0.6595 - val_accuracy: 0.6387 - val_loss: 0.6743 - learning_rate: 1.0000e-04
# Epoch 13/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6578 - loss: 0.6563 - val_accuracy: 0.6455 - val_loss: 0.6624 - learning_rate: 1.0000e-04
# Epoch 14/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.6615 - loss: 0.6547 - val_accuracy: 0.6441 - val_loss: 0.6547 - learning_rate: 1.0000e-04
# Epoch 15/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6592 - loss: 0.6548 - val_accuracy: 0.6468 - val_loss: 0.6501 - learning_rate: 1.0000e-04
# Epoch 16/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6544 - loss: 0.6561 - val_accuracy: 0.6455 - val_loss: 0.6483 - learning_rate: 1.0000e-04
# Epoch 17/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6508 - loss: 0.6578 - val_accuracy: 0.6414 - val_loss: 0.6487 - learning_rate: 1.0000e-04
# Epoch 18/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6464 - loss: 0.6598 - val_accuracy: 0.6360 - val_loss: 0.6519 - learning_rate: 1.0000e-04
# Epoch 19/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6430 - loss: 0.6616 - val_accuracy: 0.6360 - val_loss: 0.6577 - learning_rate: 1.0000e-04
# Epoch 20/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6393 - loss: 0.6631 - val_accuracy: 0.6265 - val_loss: 0.6652 - learning_rate: 1.0000e-04
# Epoch 21/50
# 81/93 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6377 - loss: 0.6673
# Epoch 21: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6406 - loss: 0.6641 - val_accuracy: 0.6225 - val_loss: 0.6728 - learning_rate: 1.0000e-04
# Epoch 22/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6646 - loss: 0.6240 - val_accuracy: 0.6955 - val_loss: 0.5985 - learning_rate: 1.0000e-05
# Epoch 23/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6764 - loss: 0.6110 - val_accuracy: 0.6955 - val_loss: 0.5986 - learning_rate: 1.0000e-05
# Epoch 24/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6761 - loss: 0.6109 - val_accuracy: 0.6942 - val_loss: 0.5985 - learning_rate: 1.0000e-05
# Epoch 25/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6762 - loss: 0.6107 - val_accuracy: 0.6942 - val_loss: 0.5983 - learning_rate: 1.0000e-05
# Epoch 26/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6774 - loss: 0.6106 - val_accuracy: 0.6928 - val_loss: 0.5982 - learning_rate: 1.0000e-05
# Epoch 27/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6766 - loss: 0.6105 - val_accuracy: 0.6915 - val_loss: 0.5980 - learning_rate: 1.0000e-05
# Epoch 28/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6760 - loss: 0.6105 - val_accuracy: 0.6915 - val_loss: 0.5979 - learning_rate: 1.0000e-05
# Epoch 29/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6764 - loss: 0.6104 - val_accuracy: 0.6915 - val_loss: 0.5978 - learning_rate: 1.0000e-05
# Epoch 30/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6768 - loss: 0.6104 - val_accuracy: 0.6915 - val_loss: 0.5977 - learning_rate: 1.0000e-05
# Epoch 31/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6753 - loss: 0.6104 - val_accuracy: 0.6915 - val_loss: 0.5976 - learning_rate: 1.0000e-05
# Epoch 32/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6750 - loss: 0.6104 - val_accuracy: 0.6915 - val_loss: 0.5975 - learning_rate: 1.0000e-05
# Epoch 33/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6766 - loss: 0.6104 - val_accuracy: 0.6928 - val_loss: 0.5974 - learning_rate: 1.0000e-05
# Epoch 34/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6777 - loss: 0.6104 - val_accuracy: 0.6928 - val_loss: 0.5973 - learning_rate: 1.0000e-05
# Epoch 35/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6735 - loss: 0.6104 - val_accuracy: 0.6928 - val_loss: 0.5972 - learning_rate: 1.0000e-05
# Epoch 36/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6748 - loss: 0.6104 - val_accuracy: 0.6928 - val_loss: 0.5971 - learning_rate: 1.0000e-05
# Epoch 37/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6750 - loss: 0.6104 - val_accuracy: 0.6915 - val_loss: 0.5970 - learning_rate: 1.0000e-05
# Epoch 38/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6742 - loss: 0.6104 - val_accuracy: 0.6928 - val_loss: 0.5968 - learning_rate: 1.0000e-05
# Epoch 39/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6736 - loss: 0.6104 - val_accuracy: 0.6928 - val_loss: 0.5967 - learning_rate: 1.0000e-05
# Epoch 40/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6735 - loss: 0.6104 - val_accuracy: 0.6928 - val_loss: 0.5966 - learning_rate: 1.0000e-05
# Epoch 41/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6745 - loss: 0.6104 - val_accuracy: 0.6928 - val_loss: 0.5965 - learning_rate: 1.0000e-05
# Epoch 42/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6740 - loss: 0.6103 - val_accuracy: 0.6928 - val_loss: 0.5964 - learning_rate: 1.0000e-05
# Epoch 43/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6732 - loss: 0.6103 - val_accuracy: 0.6928 - val_loss: 0.5963 - learning_rate: 1.0000e-05
# Epoch 44/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6716 - loss: 0.6103 - val_accuracy: 0.6915 - val_loss: 0.5962 - learning_rate: 1.0000e-05
# Epoch 45/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6721 - loss: 0.6102 - val_accuracy: 0.6915 - val_loss: 0.5961 - learning_rate: 1.0000e-05
# Epoch 46/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6710 - loss: 0.6101 - val_accuracy: 0.6915 - val_loss: 0.5960 - learning_rate: 1.0000e-05
# Epoch 47/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6711 - loss: 0.6101 - val_accuracy: 0.6915 - val_loss: 0.5959 - learning_rate: 1.0000e-05
# Epoch 48/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6713 - loss: 0.6100 - val_accuracy: 0.6915 - val_loss: 0.5958 - learning_rate: 1.0000e-05
# Epoch 49/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6723 - loss: 0.6100 - val_accuracy: 0.6915 - val_loss: 0.5957 - learning_rate: 1.0000e-05
# Epoch 50/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6726 - loss: 0.6099 - val_accuracy: 0.6915 - val_loss: 0.5957 - learning_rate: 1.0000e-05
# Restoring model weights from the end of the best epoch: 50.
# Model 3_10 - Test Loss: 0.5957, Test Accuracy: 0.6915

# %%
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np

# Predict on the test set
y_pred_probs = model_3_10.predict(X_test)  # Predicted probabilities
y_pred_classes = np.argmax(y_pred_probs, axis=1)  # Predicted classes
y_test_classes = np.argmax(y_test_onehot, axis=1)  # True classes

# Generate the confusion matrix
conf_matrix = confusion_matrix(y_test_classes, y_pred_classes)
print("Confusion Matrix:")
print(conf_matrix)

# Generate classification report
class_report = classification_report(y_test_classes, y_pred_classes, target_names=["Class 0 (low)", "Class 1 (high)"])
print("\nClassification Report:")
print(class_report)

# Optionally, calculate metrics programmatically
from sklearn.metrics import precision_score, recall_score, f1_score

precision = precision_score(y_test_classes, y_pred_classes, average='binary')  # For binary classification
recall = recall_score(y_test_classes, y_pred_classes, average='binary')
f1 = f1_score(y_test_classes, y_pred_classes, average='binary')

print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-Score: {f1:.4f}")
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Confusion Matrix:
# [[139 151]
#  [ 77 372]]
#
# Classification Report:
#                 precision    recall  f1-score   support
#
#  Class 0 (low)       0.64      0.48      0.55       290
# Class 1 (high)       0.71      0.83      0.77       449
#
#       accuracy                           0.69       739
#      macro avg       0.68      0.65      0.66       739
#   weighted avg       0.68      0.69      0.68       739
#
# Precision: 0.7113
# Recall: 0.8285
# F1-Score: 0.7654

# %% [markdown]
# # **BEST Model** (model3_b)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# -------------------------- Model 3_b -----------------------------------
# Specify Model 3_b: Same architecture as Model 3
model3_b = Sequential([
    Input(shape=(X_train.shape[1],)),
    Dense(200, activation='relu'),
    Dense(2, activation='softmax')
])

# Compile the model
model3_b.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Define callbacks with increased patience
early_stopping_monitor_3_b = EarlyStopping(
    patience=10,  # Increased patience for early stopping
    restore_best_weights=True,
    verbose=1
)

reduce_lr_3_b = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.1,
    patience=7,  # Increased patience for ReduceLROnPlateau
    min_lr=1e-6,
    verbose=1
)

# Train Model 3_b
model3_b_training = model3_b.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=100,  # Allow more epochs to observe the impact of increased patience
    callbacks=[early_stopping_monitor_3_b, reduce_lr_3_b],
    shuffle=False,
    verbose=1
)

# Evaluate Model 3_3
test_loss3_b, test_accuracy3_b = model3_b.evaluate(X_test, y_test, verbose=0)
print(f"Model 3_b - Test Loss: {test_loss3_b:.4f}, Test Accuracy: {test_accuracy3_b:.4f}")
# Out:
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5372 - loss: 21.0074 - val_accuracy: 0.6116 - val_loss: 0.9584 - learning_rate: 0.0010
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5923 - loss: 1.3762 - val_accuracy: 0.4953 - val_loss: 0.9716 - learning_rate: 0.0010
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5927 - loss: 1.1286 - val_accuracy: 0.5467 - val_loss: 0.8621 - learning_rate: 0.0010
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6206 - loss: 0.9772 - val_accuracy: 0.5494 - val_loss: 0.8233 - learning_rate: 0.0010
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6429 - loss: 0.8244 - val_accuracy: 0.4249 - val_loss: 1.2658 - learning_rate: 0.0010
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6065 - loss: 0.9823 - val_accuracy: 0.4181 - val_loss: 1.3036 - learning_rate: 0.0010
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6160 - loss: 0.9323 - val_accuracy: 0.6725 - val_loss: 0.6310 - learning_rate: 0.0010
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6511 - loss: 0.7553 - val_accuracy: 0.6685 - val_loss: 0.7864 - learning_rate: 0.0010
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6539 - loss: 0.7622 - val_accuracy: 0.6468 - val_loss: 0.6363 - learning_rate: 0.0010
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6422 - loss: 0.7335 - val_accuracy: 0.6752 - val_loss: 0.6762 - learning_rate: 0.0010
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6371 - loss: 0.8576 - val_accuracy: 0.5737 - val_loss: 0.7610 - learning_rate: 0.0010
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6106 - loss: 1.0606 - val_accuracy: 0.6834 - val_loss: 0.6340 - learning_rate: 0.0010
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6580 - loss: 0.7268 - val_accuracy: 0.6888 - val_loss: 0.6142 - learning_rate: 0.0010
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6548 - loss: 0.7013 - val_accuracy: 0.6779 - val_loss: 0.6597 - learning_rate: 0.0010
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6499 - loss: 0.7524 - val_accuracy: 0.6549 - val_loss: 0.8000 - learning_rate: 0.0010
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6384 - loss: 0.7384 - val_accuracy: 0.6698 - val_loss: 0.6882 - learning_rate: 0.0010
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6466 - loss: 0.7506 - val_accuracy: 0.6793 - val_loss: 0.6556 - learning_rate: 0.0010
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6433 - loss: 0.7595 - val_accuracy: 0.6752 - val_loss: 0.6153 - learning_rate: 0.0010
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6171 - loss: 0.9819 - val_accuracy: 0.6874 - val_loss: 0.6617 - learning_rate: 0.0010
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6596 - loss: 0.7352 - val_accuracy: 0.6766 - val_loss: 0.6083 - learning_rate: 0.0010
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6639 - loss: 0.7065 - val_accuracy: 0.6712 - val_loss: 0.6115 - learning_rate: 0.0010
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6261 - loss: 0.9684 - val_accuracy: 0.6861 - val_loss: 0.6834 - learning_rate: 0.0010
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6563 - loss: 0.7432 - val_accuracy: 0.6942 - val_loss: 0.6202 - learning_rate: 0.0010
# Epoch 24/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6593 - loss: 0.7102 - val_accuracy: 0.6793 - val_loss: 0.6136 - learning_rate: 0.0010
# Epoch 25/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6302 - loss: 0.9491 - val_accuracy: 0.6793 - val_loss: 0.6788 - learning_rate: 0.0010
# Epoch 26/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6509 - loss: 0.7536 - val_accuracy: 0.6874 - val_loss: 0.6054 - learning_rate: 0.0010
# Epoch 27/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6480 - loss: 0.8535 - val_accuracy: 0.6306 - val_loss: 1.2833 - learning_rate: 0.0010
# Epoch 28/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5879 - loss: 1.2487 - val_accuracy: 0.5737 - val_loss: 0.8011 - learning_rate: 0.0010
# Epoch 29/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6496 - loss: 0.8424 - val_accuracy: 0.4141 - val_loss: 1.4997 - learning_rate: 0.0010
# Epoch 30/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6088 - loss: 0.9507 - val_accuracy: 0.6888 - val_loss: 0.6245 - learning_rate: 0.0010
# Epoch 31/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6676 - loss: 0.7802 - val_accuracy: 0.6847 - val_loss: 0.5997 - learning_rate: 0.0010
# Epoch 32/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6620 - loss: 0.7236 - val_accuracy: 0.6563 - val_loss: 0.6245 - learning_rate: 0.0010
# Epoch 33/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6609 - loss: 0.7562 - val_accuracy: 0.6495 - val_loss: 0.6251 - learning_rate: 0.0010
# Epoch 34/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6428 - loss: 0.7931 - val_accuracy: 0.6509 - val_loss: 0.6239 - learning_rate: 0.0010
# Epoch 35/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6521 - loss: 0.8126 - val_accuracy: 0.4208 - val_loss: 1.4985 - learning_rate: 0.0010
# Epoch 36/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6210 - loss: 0.9353 - val_accuracy: 0.6847 - val_loss: 0.6063 - learning_rate: 0.0010
# Epoch 37/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6657 - loss: 0.7183 - val_accuracy: 0.6752 - val_loss: 0.6069 - learning_rate: 0.0010
# Epoch 38/100
# 63/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6783 - loss: 0.6865
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6650 - loss: 0.7249 - val_accuracy: 0.6834 - val_loss: 0.6067 - learning_rate: 0.0010
# Epoch 39/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6939 - loss: 0.5961 - val_accuracy: 0.6861 - val_loss: 0.5998 - learning_rate: 1.0000e-04
# Epoch 40/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7036 - loss: 0.5911 - val_accuracy: 0.6901 - val_loss: 0.5977 - learning_rate: 1.0000e-04
# Epoch 41/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7038 - loss: 0.5911 - val_accuracy: 0.6874 - val_loss: 0.5959 - learning_rate: 1.0000e-04
# Epoch 42/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7012 - loss: 0.5920 - val_accuracy: 0.6942 - val_loss: 0.5952 - learning_rate: 1.0000e-04
# Epoch 43/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7015 - loss: 0.5932 - val_accuracy: 0.6888 - val_loss: 0.5961 - learning_rate: 1.0000e-04
# Epoch 44/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6935 - loss: 0.5946 - val_accuracy: 0.6874 - val_loss: 0.5986 - learning_rate: 1.0000e-04
# Epoch 45/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6898 - loss: 0.5960 - val_accuracy: 0.6969 - val_loss: 0.6024 - learning_rate: 1.0000e-04
# Epoch 46/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6888 - loss: 0.5972 - val_accuracy: 0.6955 - val_loss: 0.6067 - learning_rate: 1.0000e-04
# Epoch 47/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6850 - loss: 0.5979 - val_accuracy: 0.6942 - val_loss: 0.6102 - learning_rate: 1.0000e-04
# Epoch 48/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6834 - loss: 0.5981 - val_accuracy: 0.6928 - val_loss: 0.6124 - learning_rate: 1.0000e-04
# Epoch 49/100
# 83/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6834 - loss: 0.5948
# Epoch 49: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6819 - loss: 0.5976 - val_accuracy: 0.6928 - val_loss: 0.6131 - learning_rate: 1.0000e-04
# Epoch 50/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7044 - loss: 0.5737 - val_accuracy: 0.6861 - val_loss: 0.5936 - learning_rate: 1.0000e-05
# Epoch 51/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7013 - loss: 0.5705 - val_accuracy: 0.6888 - val_loss: 0.5930 - learning_rate: 1.0000e-05
# Epoch 52/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7026 - loss: 0.5705 - val_accuracy: 0.6888 - val_loss: 0.5928 - learning_rate: 1.0000e-05
# Epoch 53/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7009 - loss: 0.5705 - val_accuracy: 0.6901 - val_loss: 0.5927 - learning_rate: 1.0000e-05
# Epoch 54/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7002 - loss: 0.5705 - val_accuracy: 0.6901 - val_loss: 0.5925 - learning_rate: 1.0000e-05
# Epoch 55/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6989 - loss: 0.5704 - val_accuracy: 0.6901 - val_loss: 0.5924 - learning_rate: 1.0000e-05
# Epoch 56/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6984 - loss: 0.5704 - val_accuracy: 0.6901 - val_loss: 0.5923 - learning_rate: 1.0000e-05
# Epoch 57/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6981 - loss: 0.5704 - val_accuracy: 0.6901 - val_loss: 0.5921 - learning_rate: 1.0000e-05
# Epoch 58/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6966 - loss: 0.5704 - val_accuracy: 0.6901 - val_loss: 0.5920 - learning_rate: 1.0000e-05
# Epoch 59/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6968 - loss: 0.5704 - val_accuracy: 0.6874 - val_loss: 0.5919 - learning_rate: 1.0000e-05
# Epoch 60/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6972 - loss: 0.5704 - val_accuracy: 0.6874 - val_loss: 0.5919 - learning_rate: 1.0000e-05
# Epoch 61/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6976 - loss: 0.5705 - val_accuracy: 0.6874 - val_loss: 0.5918 - learning_rate: 1.0000e-05
# Epoch 62/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6971 - loss: 0.5705 - val_accuracy: 0.6888 - val_loss: 0.5918 - learning_rate: 1.0000e-05
# Epoch 63/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6966 - loss: 0.5705 - val_accuracy: 0.6888 - val_loss: 0.5918 - learning_rate: 1.0000e-05
# Epoch 64/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6982 - loss: 0.5706 - val_accuracy: 0.6901 - val_loss: 0.5918 - learning_rate: 1.0000e-05
# Epoch 65/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6991 - loss: 0.5706 - val_accuracy: 0.6901 - val_loss: 0.5919 - learning_rate: 1.0000e-05
# Epoch 66/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6990 - loss: 0.5707 - val_accuracy: 0.6901 - val_loss: 0.5920 - learning_rate: 1.0000e-05
# Epoch 67/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7000 - loss: 0.5708 - val_accuracy: 0.6888 - val_loss: 0.5922 - learning_rate: 1.0000e-05
# Epoch 68/100
# 76/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7005 - loss: 0.5663
# Epoch 68: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6986 - loss: 0.5708 - val_accuracy: 0.6874 - val_loss: 0.5923 - learning_rate: 1.0000e-05
# Epoch 69/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7098 - loss: 0.5694 - val_accuracy: 0.6888 - val_loss: 0.5894 - learning_rate: 1.0000e-06
# Epoch 70/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7054 - loss: 0.5670 - val_accuracy: 0.6888 - val_loss: 0.5894 - learning_rate: 1.0000e-06
# Epoch 71/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7052 - loss: 0.5670 - val_accuracy: 0.6888 - val_loss: 0.5894 - learning_rate: 1.0000e-06
# Epoch 72/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7052 - loss: 0.5670 - val_accuracy: 0.6888 - val_loss: 0.5894 - learning_rate: 1.0000e-06
# Epoch 73/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7052 - loss: 0.5670 - val_accuracy: 0.6888 - val_loss: 0.5895 - learning_rate: 1.0000e-06
# Epoch 74/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7052 - loss: 0.5670 - val_accuracy: 0.6888 - val_loss: 0.5895 - learning_rate: 1.0000e-06
# Epoch 75/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7052 - loss: 0.5670 - val_accuracy: 0.6901 - val_loss: 0.5895 - learning_rate: 1.0000e-06
# Epoch 76/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7053 - loss: 0.5668
# Epoch 76: ReduceLROnPlateau reducing learning rate to 1e-06.
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7052 - loss: 0.5670 - val_accuracy: 0.6901 - val_loss: 0.5895 - learning_rate: 1.0000e-06
# Epoch 77/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7053 - loss: 0.5670 - val_accuracy: 0.6901 - val_loss: 0.5895 - learning_rate: 1.0000e-06
# Epoch 78/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7053 - loss: 0.5670 - val_accuracy: 0.6901 - val_loss: 0.5895 - learning_rate: 1.0000e-06
# Epoch 79/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7055 - loss: 0.5670 - val_accuracy: 0.6901 - val_loss: 0.5895 - learning_rate: 1.0000e-06
# Epoch 79: early stopping
# Restoring model weights from the end of the best epoch: 69.
# Model 3_b - Test Loss: 0.5894, Test Accuracy: 0.6888

# %%
from sklearn.metrics import roc_auc_score, roc_curve, confusion_matrix, classification_report, accuracy_score
import matplotlib.pyplot as plt
import numpy as np

# -------------------- Predictions --------------------
# Get predicted probabilities
y_pred_probs = model3_b.predict(X_test)  # Probability scores

# Get predicted classes
y_pred_classes = np.argmax(y_pred_probs, axis=1)

# True classes
y_true_classes = np.argmax(y_test, axis=1)

# -------------------- AUC and ROC Curve --------------------
# Compute AUC score
auc_score = roc_auc_score(y_true_classes, y_pred_probs[:, 1])
print(f"AUC: {auc_score:.4f}")

# Compute ROC curve
fpr, tpr, thresholds = roc_curve(y_true_classes, y_pred_probs[:, 1])

# Plot ROC curve
plt.figure()
plt.plot(fpr, tpr, label=f"ROC Curve (AUC = {auc_score:.4f})")
plt.plot([0, 1], [0, 1], "k--", label="Random Guess")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.grid()
plt.show()
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7367

# %%
# -------------------- Confusion Matrix --------------------
# Compute confusion matrix
conf_matrix = confusion_matrix(y_true_classes, y_pred_classes)
print(f"Confusion Matrix:\n{conf_matrix}")

# Visualize confusion matrix
plt.figure()
plt.matshow(conf_matrix, cmap="Blues", alpha=0.8)
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        plt.text(x=j, y=i, s=conf_matrix[i, j], ha="center", va="center")
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# -------------------- Classification Metrics --------------------
# Generate classification report
class_report = classification_report(y_true_classes, y_pred_classes, target_names=["Class 0 (low)", "Class 1 (high)"])
print("Classification Report:")
print(class_report)

# Compute precision, recall, and F1-score manually
precision = conf_matrix[1, 1] / (conf_matrix[1, 1] + conf_matrix[0, 1])
recall = conf_matrix[1, 1] / (conf_matrix[1, 1] + conf_matrix[1, 0])
f1_score = 2 * (precision * recall) / (precision + recall)

print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-Score: {f1_score:.4f}")
# Out:
# Confusion Matrix:
# [[151 139]
#  [ 91 358]]
# Classification Report:
#                 precision    recall  f1-score   support
#
#  Class 0 (low)       0.62      0.52      0.57       290
# Class 1 (high)       0.72      0.80      0.76       449
#
#       accuracy                           0.69       739
#      macro avg       0.67      0.66      0.66       739
#   weighted avg       0.68      0.69      0.68       739
#
# Precision: 0.7203
# Recall: 0.7973
# F1-Score: 0.7569

# %% [markdown]
# # **Model3_b SHAP analysis**
# https://www.datacamp.com/tutorial/introduction-to-shap-values-machine-learning-interpretability

# %%
import pandas as pd
import numpy as np
import shap

# ... your existing code ...

# Before initializing the SHAP explainer, ensure X_train has the correct data type:
# If your model was trained with a pandas DataFrame, use this:
X_train_numeric = X_train.astype(np.float32)  # Ensure all columns are numeric type

# If your model was trained with a NumPy array, you may skip this step.

# Initialize the SHAP explainer with the correctly formatted data:
explainer = shap.Explainer(model3_b, X_train_numeric)

# Compute SHAP values:
shap_values = explainer(X_train_numeric)
# Out:
# PermutationExplainer explainer: 2954it [08:22,  5.80it/s]

# %% [markdown]
# ### **Summary plot**

# %%
# Ensure all columns in X_train are numeric
X_train = X_train.apply(pd.to_numeric, errors="coerce")

# Confirm no NaN values exist after conversion
if X_train.isnull().any().any():
    print("Warning: Missing values detected!")
    print(X_train.isnull().sum())
else:
    print("No missing values in X_train after conversion.")
# Out:
# No missing values in X_train after conversion.

# %%
# Ensure feature names are explicitly extracted
feature_names = X_train.columns.tolist()
print("Feature Names:", feature_names)
# Out:
# Feature Names: ['distance', 'head', 'age', 'meanbw', 'temp', 'timetrans_min', 'lairagetime', 'season_summer', 'season_winter', 'timegr_morning', 'timegr_night']

# %%
# Convert X_train to NumPy array
X_train_np = X_train.values
print("X_train_np shape:", X_train_np.shape)
# Out:
# X_train_np shape: (2953, 11)

# %%
# Debug SHAP values
print(f"SHAP Values Shape: {shap_values.values.shape}")
# Out:
# SHAP Values Shape: (2953, 11, 2)

# %%
# Select SHAP values for the 'high' class (class index 1)
shap_values_high = shap_values.values[:, :, 1]

# Generate beeswarm plot for the 'high' class
shap.summary_plot(shap_values_high, X_train_np, feature_names=feature_names, max_display=10)

# %% [markdown]
# ### **Bar plot**

# %%
# Select SHAP values for the 'high' class (class index 1)
shap_values_class_high = shap_values[:, :, 1]  # Extract SHAP values for class 1

# Verify the shape
print(f"SHAP values for class 'high': {shap_values_class_high.shape}")  # Should be (2953, 11)

# Generate the bar plot for feature importance
shap.summary_plot(shap_values_class_high, X_train_np, plot_type="bar", feature_names=feature_names)
# Out:
# SHAP values for class 'high': (2953, 11)

# %% [markdown]
# ### **Dependence plot**

# %%
pip install shap --upgrade
# Out:
# Requirement already satisfied: shap in /usr/local/lib/python3.10/dist-packages (0.46.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from shap) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from shap) (1.13.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from shap) (1.5.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from shap) (2.2.2)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.10/dist-packages (from shap) (4.66.6)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.10/dist-packages (from shap) (24.2)
# Requirement already satisfied: slicer==0.0.8 in /usr/local/lib/python3.10/dist-packages (from shap) (0.0.8)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from shap) (0.60.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from shap) (3.1.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->shap) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2024.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->shap) (1.16.0)

# %% [markdown]
# ### **Select top 5 important variables**
# head, temp, timetrans_min, distance, timegr_morning

# %%
X_train_np = np.array(X_train_np, dtype=float)  # Ensure features are numeric
shap_values_high = np.array(shap_values_high)   # Ensure SHAP values are numeric

# %%
import shap
import matplotlib.pyplot as plt

# Plot dependence for a single feature
plt.figure()
try:
    shap.dependence_plot(
        ind=1,  # Feature index for 'head'
        shap_values=shap_values_high,  # SHAP values for the 'high' class
        features=X_train_np,  # Feature dataset
        feature_names=feature_names,  # List of feature names
    )
    plt.show()
except Exception as e:
    print(f"Error generating dependence plot: {e}")

# %%
import shap
import matplotlib.pyplot as plt

# Plot dependence for a single feature
plt.figure()
try:
    shap.dependence_plot(
        ind=4,  # Feature index for 'temp'
        shap_values=shap_values_high,  # SHAP values for the 'high' class
        features=X_train_np,  # Feature dataset
        feature_names=feature_names,  # List of feature names
    )
    plt.show()
except Exception as e:
    print(f"Error generating dependence plot: {e}")

# %%
import shap
import matplotlib.pyplot as plt

# Plot dependence for a single feature
plt.figure()
try:
    shap.dependence_plot(
        ind=5,  # Feature index for 'timetrans_min'
        shap_values=shap_values_high,  # SHAP values for the 'high' class
        features=X_train_np,  # Feature dataset
        feature_names=feature_names,  # List of feature names
    )
    plt.show()
except Exception as e:
    print(f"Error generating dependence plot: {e}")

# %%
import shap
import matplotlib.pyplot as plt

# Plot dependence for a single feature
plt.figure()
try:
    shap.dependence_plot(
        ind=0,  # Feature index for 'distance'
        shap_values=shap_values_high,  # SHAP values for the 'high' class
        features=X_train_np,  # Feature dataset
        feature_names=feature_names,  # List of feature names
    )
    plt.show()
except Exception as e:
    print(f"Error generating dependence plot: {e}")

# %%
import shap
import matplotlib.pyplot as plt

# Plot dependence for a single feature
plt.figure()
try:
    shap.dependence_plot(
        ind=7,  # Feature index for 'season_summer'
        shap_values=shap_values_high,  # SHAP values for the 'high' class
        features=X_train_np,  # Feature dataset
        feature_names=feature_names,  # List of feature names
    )
    plt.show()
except Exception as e:
    print(f"Error generating dependence plot: {e}")

# %% [markdown]
# ### **Force plot**

# %%
# Calculate the expected value (mean prediction for the 'high' class)
expected_value = np.mean(model3_b.predict(X_train_numeric)[:, 1])  # Mean probability for the 'high' class
# Out:
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
import shap

shap.initjs()  # Initialize JavaScript visualization
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...

# %% [markdown]
# ### **Force plot for lowest doapct instance**
# instance 1 (index = 0), doapct = 0

# %%
import shap
import matplotlib.pyplot as plt

# Select one instance to explain (e.g., the first row of your dataset)
instance_index = 0  # Replace with the row index you want to visualize
shap_values_single_0 = shap_values.values[instance_index, :, 1]  # SHAP values for 'high' class
features_single_0 = X_train_np[instance_index, :]  # Feature values for the selected instance

# Generate the force plot
shap.initjs()  # Initialize JavaScript for visualization
force_plot_0 = shap.force_plot(
    base_value=expected_value,  # Manually calculated expected value
    shap_values=shap_values_single_0,  # SHAP values for the selected instance
    features=features_single_0,  # Feature values for the selected instance
    feature_names=feature_names  # Feature names
)

# Display the plot
force_plot_0
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# <div id='i8HYF9SXMECOSFOGYR3XK'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.5976312756538391, "outValue": 0.9249859770310909, "link": "identity", "featureNames": ["distance", "head", "age", "meanbw", "temp", "timetrans_min", "lairagetime", "season_summer", "season_winter", "timegr_morning", "timegr_night"], "features": {"0": {"effect": -0.03692643930343124, "value": 40.0}, "1": {"effect": 0.19416123942254304, "value": 1400.0}, "2": {"effect": -0.002259585512469386, "value": 42.0}, "3": {"effect": 0.01470077446671352, "value": 3.35}, "4": {"effect": 0.1331286514301749, "value": 26.2}, "5": {"effect": 0.06491314420165285, "value": 45.0}, "6": {"effect": -0.058812968835282205, "value": 174.0}, "7": {"effect": -0.01320637545437508, "value": 0.0}, "8": {"effect": -0.003562309689458582, "value": 0.0}, "9": {"effect": 0.03885277144101023, "value": 1.0}, "10": {"effect": -0.003634200789826273, "value": 0.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i8HYF9SXMECOSFOGYR3XK')
#   );
# </script>

# %%
import matplotlib.pyplot as plt

# Plot the SHAP values for a single instance as a horizontal bar plot
plt.barh(feature_names, shap_values_single_0)
plt.xlabel("SHAP value")
plt.ylabel("Feature")
plt.title("Feature contributions for instance1")
plt.show()

# %% [markdown]
# ## **Force plot for highest doapct instance**

# %%
highest_doapct_index = df['doapct'].idxmax()  # Index of the instance with the highest doapct

# %%
instance_to_explain = X_train.iloc[highest_doapct_index, :]

# %%
import shap
import matplotlib.pyplot as plt

# Select the SHAP values for the identified instance
shap_values_single = shap_values.values[highest_doapct_index, :, 1]  # SHAP values for the 'high' class
features_single = X_train_np[highest_doapct_index, :]  # Feature values for the selected instance

# Generate the force plot
shap.initjs()  # Initialize JavaScript for visualization
force_plot = shap.force_plot(
    base_value=expected_value,  # Manually calculated expected value
    shap_values=shap_values_single,  # SHAP values for the selected instance
    features=features_single,  # Feature values for the selected instance
    feature_names=feature_names  # Feature names
)

# Display the plot
force_plot
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# <div id='iXWNREK8PK3YR9OUDOCUZ'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.5976312756538391, "outValue": 0.9047612858974441, "link": "identity", "featureNames": ["distance", "head", "age", "meanbw", "temp", "timetrans_min", "lairagetime", "season_summer", "season_winter", "timegr_morning", "timegr_night"], "features": {"0": {"effect": -0.03559898314921028, "value": 50.0}, "1": {"effect": -0.004309155864375284, "value": 1200.0}, "2": {"effect": -0.002647632565127601, "value": 42.0}, "3": {"effect": 0.01680129563435751, "value": 3.358333333333333}, "4": {"effect": 0.1775687689632734, "value": 25.4}, "5": {"effect": 0.04125100059050933, "value": 79.0}, "6": {"effect": 0.005790550444231674, "value": 122.0}, "7": {"effect": 0.07133652954659986, "value": 1.0}, "8": {"effect": -0.003996765073325172, "value": 0.0}, "9": {"effect": 0.04493814977133415, "value": 1.0}, "10": {"effect": -0.0040037480546625615, "value": 0.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iXWNREK8PK3YR9OUDOCUZ')
#   );
# </script>

# %% [markdown]
# ### **Decision plot**

# %%
import shap
import matplotlib.pyplot as plt

# Select an instance to explain (e.g., the first row)
instance_index = 0  # Replace with the desired row index

# Generate a decision plot
shap.decision_plot(
    base_value=expected_value,                # Manually calculated expected value
    shap_values=shap_values.values[instance_index, :, 1],  # SHAP values for the 'high' class
    feature_names=feature_names,             # Feature names
    feature_order="importance",              # Optional: Order features by importance
    highlight=0                              # Optional: Highlight the selected instance
)

# Display the plot
plt.show()

# %%
import shap
import matplotlib.pyplot as plt

# Generate a decision plot for all instances
shap.decision_plot(
    base_value=expected_value,                # Manually calculated expected value
    shap_values=shap_values.values[:, :, 1],  # SHAP values for the 'high' class (all instances)
    feature_names=feature_names,             # Feature names
    feature_order="importance",              # Order features by importance
    ignore_warnings=True                     # Ignore warnings about large datasets
)
plt.show()

# %% [markdown]
# ### ▶ ALL DONE ◀
